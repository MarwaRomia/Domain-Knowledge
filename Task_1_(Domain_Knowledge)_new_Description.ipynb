# %% [markdown]
# # Task 1 (Domain Knowledge)
#
# now you are a data scientist at one of the biggest health care organization and your manager doesn`t have back ground about data and there is a big project to predict if the patiant have a heart disease or not so your organization paid for this data it consist of 70000 record and after the manager look at this data he told you that he doesn`t understand what the number in column age mean so he asks you to create function to solve the age column (read the discription below to discover what you will do 'create function to convert age from days to years') also you manager told you there is a missing feature called (Body Mass Index) this will help the organization to predict the disease well (the below figure there is the formula to calculate BMI)
# ## Features:
#
# >>>Age | Objective Feature | age | int (days)
# >Height | Objective Feature | height | int (cm) |
# >Weight | Objective Feature | weight | float (kg) |
# >Gender | Objective Feature | gender | categorical code |
# >Systolic blood pressure | Examination Feature | ap_hi | int |
# >Diastolic blood pressure | Examination Feature | ap_lo | int |
# >Cholesterol | Examination Feature | cholesterol | 1: normal, 2: above normal, 3: well above normal |
# >Glucose | Examination Feature | gluc | 1: normal, 2: above normal, 3: well above normal |
# >Smoking | Subjective Feature | smoke | binary |
# >Alcohol intake | Subjective Feature | alco | binary |
# >Physical activity | Subjective Feature | active | binary |
# >Presence or absence of cardiovascular disease | Target Variable | cardio | binary |
#
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# **Read your dataset**

# %%
df = pd.read_csv('cardio_train.csv',';')
df.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# **Modify the AGE Column to make it understandable ( Make the AGE in Years not in Days )**

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
df['age']
# Out:
# 0        18393
# 1        20228
# 2        18857
# 3        17623
# 4        17474
#          ...
# 69995    19240
# 69996    22601
# 69997    19066
# 69998    22431
# 69999    20540
# Name: age, Length: 70000, dtype: int64

# %%
y=[]
for i in df['age']:
    yr=round(i/365)
    y.append(yr)

# %%
y
# Out:
# [50,
#  55,
#  52,
#  48,
#  48,
#  60,
#  61,
#  62,
#  48,
#  54,
#  62,
#  52,
#  41,
#  54,
#  40,
#  46,
#  58,
#  46,
#  48,
#  60,
#  54,
#  59,
#  63,
#  64,
#  46,
#  40,
#  54,
#  50,
#  40,
#  58,
#  50,
#  64,
#  40,
#  57,
#  60,
#  56,
#  50,
#  49,
#  64,
#  50,
#  54,
#  50,
#  59,
#  56,
#  54,
#  48,
#  50,
#  51,
#  46,
#  44,
#  50,
#  50,
#  54,
#  40,
#  54,
#  60,
#  48,
#  62,
#  44,
#  56,
#  52,
#  57,
#  56,
#  62,
#  57,
#  60,
#  52,
#  61,
#  54,
#  57,
#  65,
#  60,
#  64,
#  60,
#  44,
#  56,
#  56,
#  60,
#  50,
#  56,
#  45,
#  52,
#  54,
#  54,
#  62,
#  50,
#  60,
#  54,
#  64,
#  53,
#  64,
#  54,
#  51,
#  63,
#  44,
#  58,
#  53,
#  50,
#  60,
#  48,
#  40,
#  51,
#  47,
#  50,
#  60,
#  57,
#  40,
#  40,
#  42,
#  44,
#  64,
#  58,
#  46,
#  52,
#  60,
#  60,
#  52,
#  54,
#  39,
#  50,
#  59,
#  53,
#  50,
#  40,
#  60,
#  54,
#  58,
#  60,
#  61,
#  50,
#  60,
#  56,
#  62,
#  58,
#  59,
#  56,
#  47,
#  62,
#  46,
#  50,
#  54,
#  60,
# ...

# %%
df['age']=y
df['age']
# Out:
# 0        50
# 1        55
# 2        52
# 3        48
# 4        48
#          ..
# 69995    53
# 69996    62
# 69997    52
# 69998    61
# 69999    56
# Name: age, Length: 70000, dtype: int64

# %% [markdown]
# **Create the new feature BMI as per the previous description**

# %%
df['height']
# Out:
# 0        168
# 1        156
# 2        165
# 3        169
# 4        156
#         ...
# 69995    168
# 69996    158
# 69997    183
# 69998    163
# 69999    170
# Name: height, Length: 70000, dtype: int64

# %%
df['weight']
# Out:
# 0         62.0
# 1         85.0
# 2         64.0
# 3         82.0
# 4         56.0
#          ...
# 69995     76.0
# 69996    126.0
# 69997    105.0
# 69998     72.0
# 69999     72.0
# Name: weight, Length: 70000, dtype: float64

# %%
#BMI = weight / (height/100)**2
df['bmi']=df['weight']/(df['height'])**2
df['bmi']
# Out:
# 0        0.002197
# 1        0.003493
# 2        0.002351
# 3        0.002871
# 4        0.002301
#            ...
# 69995    0.002693
# 69996    0.005047
# 69997    0.003135
# 69998    0.002710
# 69999    0.002491
# Name: bmi, Length: 70000, dtype: float64
